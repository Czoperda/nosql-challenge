# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db["establishments"]
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food'), 'establishments')

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
count_20_hygiene = establishments.count_documents(query)
# Display the first document in the results using pprint
first_document_20_hygiene = establishments.find_one(query)
pprint(first_document_20_hygiene)
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'Latitude': None,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'Longitude': None,
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65f78167053ea62b7c339014'),
#  'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
result = establishments.find(query)
df = pd.DataFrame(list(result))

# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame:", len(df))

# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# Number of rows in the DataFrame: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  65f78167053ea62b7c339014   110681                  0
# 1  65f78167053ea62b7c339395   612039                  0
# 2  65f78167053ea62b7c33969f   730933                  0
# 3  65f78167053ea62b7c33988d   172735                  0
# 4  65f78167053ea62b7c33989c   172953                  0
# 5  65f78168053ea62b7c33a23b   512854                  0
# 6  65f78168053ea62b7c33a45c  1537089                  0
# 7  65f78169053ea62b7c33b987   155648                  0
# 8  65f78169053ea62b7c33bdcb  1012883                  0
# 9  65f78169053ea62b7c33c5dd   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '0.27694', 'latitude': '50.769705'}
# 1  {'longitude': '1.278721', 'latitude': '51.8575...
# 2  {'longitude': '1.15927', 'latitude': '51.789429'}
# 3  {'longitude': '0.10202', 'latitude': '50.770885'}
# 4  {'longitude': '0.101446', 'latitude': '50.7707...
# 5  {'longitude': '0.736349', 'latitude': '51.5414...
# 6  {'longitude': '0.7121671', 'latitude': '51.535...
# 7  {'longitude': '0.602364', 'latitude': '51.5915...
# 8  {'longitude': '0.146449998021126', 'latitude':...
# 9  {'longitude': '0.462307', 'latitude': '51.57005'}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links Latitude Longitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 1  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 2  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 3  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 4  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 5  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 6  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    "AddressLine4": "London",
    "RatingValue": {"$gte": 4}
}

# Use count_documents to display the number of documents in the result
count_documents = establishments.count_documents(query)
# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# {'AddressLine1': 'Arch D',
#  'AddressLine2': 'The Link Thamesmead',
#  'AddressLine3': 'Bazalgette Way',
#  'AddressLine4': 'London',
#  'BusinessName': 'The Mezzanine Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4646.357884390823,
#  'FHRSID': 1049722,
#  'Latitude': None,
#  'LocalAuthorityBusinessID': '18/00096/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'Longitude': None,
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE2 9BS',
#  'RatingDate': '2022-05-24T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65f7816b053ea62b7c33e4c6'),
#  'geocode': {'latitude': '51.5002632141113', 'longitude': '0.121751002967358'},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1049722',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 10, 'Structural': 0}}

# %%
# Convert the result to a Pandas DataFrame
result = establishments.find(query)
df = pd.DataFrame(list(result))
# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame:", len(df))
# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# Number of rows in the DataFrame: 390
#                         _id   FHRSID  ChangesByServerID  \
# 0  65f7816b053ea62b7c33e4c6  1049722                  0
# 1  65f7816b053ea62b7c33e4e7  1261451                  0
# 2  65f7816b053ea62b7c33e4ec   987733                  0
# 3  65f7816b053ea62b7c33e4ed   357627                  0
# 4  65f7816b053ea62b7c33e50a  1151706                  0
# 5  65f7816b053ea62b7c33e50e  1468037                  0
# 6  65f7816b053ea62b7c33e50f   358232                  0
# 7  65f7816b053ea62b7c33e519  1415217                  0
# 8  65f7816b053ea62b7c33e52c   635108                  0
# 9  65f7816b053ea62b7c33e52d   357579                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0              18/00096/CP                                 The Mezzanine Cafe
# 1           20/00255/MIXED  St Edward's Church, Mottingham - StEP Lunch Cl...
# 2           16/00340/MIXED                             Maryfield Pre-School 2
# 3         00000/0000/8/951                                              Co-op
# 4         00000/0000/8/204               North Hub @ Castlecombe Youth Centre
# 5           22/00180/MIXED                                           Spencers
# 6           02/00010/MIXED                                     Domino's Pizza
# 7           21/00630/MIXED                                  Papa John's Pizza
# 8           14/00056/MIXED                                       Perfect Cafe
# 9         00000/0000/8/062                                  Superfry Fish Bar
#
#                             BusinessType  BusinessTypeID  \
# 0                Restaurant/Cafe/Canteen               1
# 1                Other catering premises            7841
# 2                        Caring Premises               5
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                        Caring Premises               5
# 5                      Retailers - other            4613
# 6                 Takeaway/sandwich shop            7844
# 7                 Takeaway/sandwich shop            7844
# 8                Restaurant/Cafe/Canteen               1
# 9                 Takeaway/sandwich shop            7844
#
#                   AddressLine1         AddressLine2    AddressLine3  ...  \
# 0                       Arch D  The Link Thamesmead  Bazalgette Way  ...
# 1       St Edwards Church Hall      St Keverne Road      Mottingham  ...
# 2  Mottingham Community Centre      Kimmeridge Road      Mottingham  ...
# 3        The Co-operative Food      Kimmeridge Road      Mottingham  ...
# 4     Castlecombe Youth Centre     Castlecombe Road      Mottingham  ...
# 5            11 Cranley Parade      Kimmeridge Road      Mottingham  ...
# 6             3 Cranley Parade    Beaconsfield Road      Mottingham  ...
# 7             4 Cranley Parade    Beaconsfield Road      Mottingham  ...
# 8       11 Beaconsfield Parade    Beaconsfield Road      Mottingham  ...
# 9       12 Beaconsfield Parade    Beaconsfield Road      Mottingham  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 10, 'Structural': 0, 'ConfidenceIn...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 5  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
# 6  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '0.121751002967358', 'latitude':...
# 1  {'longitude': '0.04774', 'latitude': '51.428019'}
# 2  {'longitude': '0.0465259999036789', 'latitude'...
# 3  {'longitude': '0.0465259999036789', 'latitude'...
# 4  {'longitude': '0.0433179996907711', 'latitude'...
# 5  {'longitude': '0.046141', 'latitude': '51.4273...
# 6  {'longitude': '0.046141', 'latitude': '51.4273...
# 7  {'longitude': '0.0460971', 'latitude': '51.427...
# 8  {'longitude': '0.045445', 'latitude': '51.4271...
# 9  {'longitude': '0.045445', 'latitude': '51.4271...
#
#       Distance NewRatingPending  \
# 0  4646.357884            False
# 1  4646.410908            False
# 2  4646.414831            False
# 3  4646.414831            False
# 4  4646.439635            False
# 5  4646.443677            False
# 6  4646.443677            False
# 7  4646.448256            False
# 8  4646.464277            False
# 9  4646.464277            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links Latitude Longitude
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
penang = establishments.find_one({"BusinessName": "Penang Flavours"},
                                                    {"_id": 0, "Latitude": 1, "Longitude": 1})
degree_search = 0.01
latitude = penang["Latitude"]
longitude = penang["Longitude"]

query = {
    "RatingValue": 5,
    "Latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "Longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search}
}
sort = [("scores.Hygiene", 1)]
limit = 5

# Print the results
results = establishments.find(query).sort(sort).limit(limit)
pprint(results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 12
#       7 latitude = penang["Latitude"]
#       8 longitude = penang["Longitude"]
#      10 query = {
#      11     "RatingValue": 5,
# ---> 12     "Latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
#      13     "Longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search}
#      14 }
#      15 sort = [("scores.Hygiene", 1)]
#      16 limit = 5
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'float'

# %%
# Convert result to Pandas DataFrame
results = establishments.find(query)
df = pd.DataFrame(list(results))

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}}, 
    {"$sort": {"count": -1}}
]
result = list(establishments.aggregate(pipeline))
# Print the number of documents in the result
print("Number of documents in result: ", len(result))
# Print the first 10 results
pprint(result[0:10])
# Out:
# Number of documents in result:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
result = establishments.find(query)
df = pd.DataFrame(list(result))
# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame:", len(df))
# Display the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# Number of rows in the DataFrame: 390
#                         _id   FHRSID  ChangesByServerID  \
# 0  65f7816b053ea62b7c33e4c6  1049722                  0
# 1  65f7816b053ea62b7c33e4e7  1261451                  0
# 2  65f7816b053ea62b7c33e4ec   987733                  0
# 3  65f7816b053ea62b7c33e4ed   357627                  0
# 4  65f7816b053ea62b7c33e50a  1151706                  0
# 5  65f7816b053ea62b7c33e50e  1468037                  0
# 6  65f7816b053ea62b7c33e50f   358232                  0
# 7  65f7816b053ea62b7c33e519  1415217                  0
# 8  65f7816b053ea62b7c33e52c   635108                  0
# 9  65f7816b053ea62b7c33e52d   357579                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0              18/00096/CP                                 The Mezzanine Cafe
# 1           20/00255/MIXED  St Edward's Church, Mottingham - StEP Lunch Cl...
# 2           16/00340/MIXED                             Maryfield Pre-School 2
# 3         00000/0000/8/951                                              Co-op
# 4         00000/0000/8/204               North Hub @ Castlecombe Youth Centre
# 5           22/00180/MIXED                                           Spencers
# 6           02/00010/MIXED                                     Domino's Pizza
# 7           21/00630/MIXED                                  Papa John's Pizza
# 8           14/00056/MIXED                                       Perfect Cafe
# 9         00000/0000/8/062                                  Superfry Fish Bar
#
#                             BusinessType  BusinessTypeID  \
# 0                Restaurant/Cafe/Canteen               1
# 1                Other catering premises            7841
# 2                        Caring Premises               5
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                        Caring Premises               5
# 5                      Retailers - other            4613
# 6                 Takeaway/sandwich shop            7844
# 7                 Takeaway/sandwich shop            7844
# 8                Restaurant/Cafe/Canteen               1
# 9                 Takeaway/sandwich shop            7844
#
#                   AddressLine1         AddressLine2    AddressLine3  ...  \
# 0                       Arch D  The Link Thamesmead  Bazalgette Way  ...
# 1       St Edwards Church Hall      St Keverne Road      Mottingham  ...
# 2  Mottingham Community Centre      Kimmeridge Road      Mottingham  ...
# 3        The Co-operative Food      Kimmeridge Road      Mottingham  ...
# 4     Castlecombe Youth Centre     Castlecombe Road      Mottingham  ...
# 5            11 Cranley Parade      Kimmeridge Road      Mottingham  ...
# 6             3 Cranley Parade    Beaconsfield Road      Mottingham  ...
# 7             4 Cranley Parade    Beaconsfield Road      Mottingham  ...
# 8       11 Beaconsfield Parade    Beaconsfield Road      Mottingham  ...
# 9       12 Beaconsfield Parade    Beaconsfield Road      Mottingham  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 10, 'Structural': 0, 'ConfidenceIn...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 5  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
# 6  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '0.121751002967358', 'latitude':...
# 1  {'longitude': '0.04774', 'latitude': '51.428019'}
# 2  {'longitude': '0.0465259999036789', 'latitude'...
# 3  {'longitude': '0.0465259999036789', 'latitude'...
# 4  {'longitude': '0.0433179996907711', 'latitude'...
# 5  {'longitude': '0.046141', 'latitude': '51.4273...
# 6  {'longitude': '0.046141', 'latitude': '51.4273...
# 7  {'longitude': '0.0460971', 'latitude': '51.427...
# 8  {'longitude': '0.045445', 'latitude': '51.4271...
# 9  {'longitude': '0.045445', 'latitude': '51.4271...
#
#       Distance NewRatingPending  \
# 0  4646.357884            False
# 1  4646.410908            False
# 2  4646.414831            False
# 3  4646.414831            False
# 4  4646.439635            False
# 5  4646.443677            False
# 6  4646.443677            False
# 7  4646.448256            False
# 8  4646.464277            False
# 9  4646.464277            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links Latitude Longitude
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
#
# [10 rows x 30 columns]
